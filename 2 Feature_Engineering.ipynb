# %% [markdown]
# Взглянем на все фичи, что у нас есть, попробуем придумать новые, избавимся от ненужных, преобразуем категориальные и ординальные в числовые.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('dark_background')
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
train_df = pd.read_csv('./content/train.csv')

# %%
train_df.columns.to_frame()
# Out:
#                        0
# PassengerId  PassengerId
# Survived        Survived
# Pclass            Pclass
# Name                Name
# Sex                  Sex
# Age                  Age
# SibSp              SibSp
# Parch              Parch
# Ticket            Ticket
# Fare                Fare
# Cabin              Cabin
# Embarked        Embarked

# %% [markdown]
# # Работа с null-значениями
#
# Посмотрим сначала какие фичи имеют null-значения:

# %%
train_df.isnull().any()
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name           False
# Sex            False
# Age             True
# SibSp          False
# Parch          False
# Ticket         False
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %% [markdown]
# Видим, null-значения присутствуют в *Age*, *Cabin* и *Embarked*. Фича *Cabin* не учавствует в обучении модели, поэтому не обращаем на неё внимаем, а вот *Age* и *Embarked* рассмотрим подробнее:

# %%
print(f'Count null-value Age is {train_df['Age'].isnull().sum()} \nCount null-value Embarked is {train_df['Embarked'].isnull().sum()} \n\nAll samples is {train_df.shape[0]}')
# Out:
# Count null-value Age is 177
# Count null-value Embarked is 2
#
# All samples is 891

# %% [markdown]
# ## Embarked null
#
# В столбце *Embarked* всего-лишь 2 null-значений. Их можно заполнить самым частым значением:

# %%
train_df['Embarked'].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
train_df.loc[train_df['Embarked'].isnull(), 'Embarked'] = 'S'

# %%
train_df['Embarked'].value_counts()
# Out:
# Embarked
# S    646
# C    168
# Q     77
# Name: count, dtype: int64

# %% [markdown]
# ## Age null
#
# В *Age* null-значений уже 177 из 891. Можно было бы заполнить их средним значением общего количества людей или средним значением в зависимости от пола.\
# Но если посмотреть в данные, у каждого из людей в имени есть их "почётные титулы":

# %%
train_df['Name'].head(10)
# Out:
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# 5                                     Moran, Mr. James
# 6                              McCarthy, Mr. Timothy J
# 7                       Palsson, Master. Gosta Leonard
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                  Nasser, Mrs. Nicholas (Adele Achem)
# Name: Name, dtype: str

# %% [markdown]
# Среди них встречаются такие титулы как *Mr.*, *Mrs*, *Miss.*, *Master.* и ещё несколько. *Mr* могут называть взрослого мужчину, а *Master* мальчика.\
# Выделим у каждого из них своё почётный титул и посмотрим на среднее значение возраста каждого титула:

# %%
train_df['Honorifics'] = train_df['Name'].str.extract('([A-Z][a-z]+)\.', expand=True)
train_df[['Name', 'Honorifics']]
# Out:
#                                                   Name Honorifics
# 0                              Braund, Mr. Owen Harris         Mr
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...        Mrs
# 2                               Heikkinen, Miss. Laina       Miss
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)        Mrs
# 4                             Allen, Mr. William Henry         Mr
# ..                                                 ...        ...
# 886                              Montvila, Rev. Juozas        Rev
# 887                       Graham, Miss. Margaret Edith       Miss
# 888           Johnston, Miss. Catherine Helen "Carrie"       Miss
# 889                              Behr, Mr. Karl Howell         Mr
# 890                                Dooley, Mr. Patrick         Mr
#
# [891 rows x 2 columns]

# %%
pd.crosstab(index=train_df['Sex'], columns=train_df['Honorifics']).style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_a0df3_row0_col0, #T_a0df3_row0_col1, #T_a0df3_row0_col3, #T_a0df3_row0_col4, #T_a0df3_row0_col5, #T_a0df3_row0_col7, #T_a0df3_row0_col8, #T_a0df3_row0_col12, #T_a0df3_row0_col15, #T_a0df3_row0_col16, #T_a0df3_row1_col2, #T_a0df3_row1_col6, #T_a0df3_row1_col9, #T_a0df3_row1_col10, #T_a0df3_row1_col11, #T_a0df3_row1_col13, #T_a0df3_row1_col14 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_a0df3_row0_col2, #T_a0df3_row0_col6, #T_a0df3_row0_col9, #T_a0df3_row0_col10, #T_a0df3_row0_col11, #T_a0df3_row0_col13, #T_a0df3_row0_col14, #T_a0df3_row1_col0, #T_a0df3_row1_col1, #T_a0df3_row1_col3, #T_a0df3_row1_col4, #T_a0df3_row1_col5, #T_a0df3_row1_col7, #T_a0df3_row1_col8, #T_a0df3_row1_col12, #T_a0df3_row1_col15, #T_a0df3_row1_col16 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_a0df3">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Honorifics</th>
#       <th id="T_a0df3_level0_col0" class="col_heading level0 col0" >Capt</th>
#       <th id="T_a0df3_level0_col1" class="col_heading level0 col1" >Col</th>
#       <th id="T_a0df3_level0_col2" class="col_heading level0 col2" >Countess</th>
#       <th id="T_a0df3_level0_col3" class="col_heading level0 col3" >Don</th>
#       <th id="T_a0df3_level0_col4" class="col_heading level0 col4" >Dr</th>
#       <th id="T_a0df3_level0_col5" class="col_heading level0 col5" >Jonkheer</th>
#       <th id="T_a0df3_level0_col6" class="col_heading level0 col6" >Lady</th>
#       <th id="T_a0df3_level0_col7" class="col_heading level0 col7" >Major</th>
#       <th id="T_a0df3_level0_col8" class="col_heading level0 col8" >Master</th>
#       <th id="T_a0df3_level0_col9" class="col_heading level0 col9" >Miss</th>
#       <th id="T_a0df3_level0_col10" class="col_heading level0 col10" >Mlle</th>
#       <th id="T_a0df3_level0_col11" class="col_heading level0 col11" >Mme</th>
#       <th id="T_a0df3_level0_col12" class="col_heading level0 col12" >Mr</th>
#       <th id="T_a0df3_level0_col13" class="col_heading level0 col13" >Mrs</th>
#       <th id="T_a0df3_level0_col14" class="col_heading level0 col14" >Ms</th>
#       <th id="T_a0df3_level0_col15" class="col_heading level0 col15" >Rev</th>
#       <th id="T_a0df3_level0_col16" class="col_heading level0 col16" >Sir</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Sex</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a0df3_level0_row0" class="row_heading level0 row0" >female</th>
#       <td id="T_a0df3_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_a0df3_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_a0df3_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_a0df3_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_a0df3_row0_col4" class="data row0 col4" >1</td>
#       <td id="T_a0df3_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_a0df3_row0_col6" class="data row0 col6" >1</td>
#       <td id="T_a0df3_row0_col7" class="data row0 col7" >0</td>
#       <td id="T_a0df3_row0_col8" class="data row0 col8" >0</td>
#       <td id="T_a0df3_row0_col9" class="data row0 col9" >182</td>
#       <td id="T_a0df3_row0_col10" class="data row0 col10" >2</td>
#       <td id="T_a0df3_row0_col11" class="data row0 col11" >1</td>
#       <td id="T_a0df3_row0_col12" class="data row0 col12" >0</td>
#       <td id="T_a0df3_row0_col13" class="data row0 col13" >125</td>
#       <td id="T_a0df3_row0_col14" class="data row0 col14" >1</td>
#       <td id="T_a0df3_row0_col15" class="data row0 col15" >0</td>
#       <td id="T_a0df3_row0_col16" class="data row0 col16" >0</td>
#     </tr>
#     <tr>
#       <th id="T_a0df3_level0_row1" class="row_heading level0 row1" >male</th>
#       <td id="T_a0df3_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_a0df3_row1_col1" class="data row1 col1" >2</td>
#       <td id="T_a0df3_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_a0df3_row1_col3" class="data row1 col3" >1</td>
#       <td id="T_a0df3_row1_col4" class="data row1 col4" >6</td>
#       <td id="T_a0df3_row1_col5" class="data row1 col5" >1</td>
#       <td id="T_a0df3_row1_col6" class="data row1 col6" >0</td>
#       <td id="T_a0df3_row1_col7" class="data row1 col7" >2</td>
#       <td id="T_a0df3_row1_col8" class="data row1 col8" >40</td>
#       <td id="T_a0df3_row1_col9" class="data row1 col9" >0</td>
#       <td id="T_a0df3_row1_col10" class="data row1 col10" >0</td>
#       <td id="T_a0df3_row1_col11" class="data row1 col11" >0</td>
#       <td id="T_a0df3_row1_col12" class="data row1 col12" >517</td>
#       <td id="T_a0df3_row1_col13" class="data row1 col13" >0</td>
#       <td id="T_a0df3_row1_col14" class="data row1 col14" >0</td>
#       <td id="T_a0df3_row1_col15" class="data row1 col15" >6</td>
#       <td id="T_a0df3_row1_col16" class="data row1 col16" >1</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Видно, что есть редкие титулы: *Capt*, *Col*, *Countess*, *Don*, *Dr*, *Jonkheer*, *Lady*, *Major*, *Rev* и *Sir*.\
# А если синонимы: *Mlle* и *Ms* означает то же самое, что и *Miss*, а *Mme* означает *Mrs*.
#
# Синонимы лучше объеденить в самый популярный титул, а редкие титулы в *Rare*:

# %%
train_df['Honorifics'] = train_df['Honorifics'].replace(['Capt', 'Col', 'Countess', 'Don', 'Dr', 'Jonkheer', 'Lady', 'Major', 'Rev', 'Sir'], 'Rare')
train_df['Honorifics'] = train_df['Honorifics'].replace(['Mlle', 'Ms'], 'Miss')
train_df['Honorifics'] = train_df['Honorifics'].replace('Mme', 'Mrs')

pd.crosstab(index=train_df['Sex'], columns=train_df['Honorifics']).style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_0d213_row0_col0, #T_0d213_row0_col2, #T_0d213_row0_col4, #T_0d213_row1_col1, #T_0d213_row1_col3 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_0d213_row0_col1, #T_0d213_row0_col3, #T_0d213_row1_col0, #T_0d213_row1_col2, #T_0d213_row1_col4 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_0d213">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Honorifics</th>
#       <th id="T_0d213_level0_col0" class="col_heading level0 col0" >Master</th>
#       <th id="T_0d213_level0_col1" class="col_heading level0 col1" >Miss</th>
#       <th id="T_0d213_level0_col2" class="col_heading level0 col2" >Mr</th>
#       <th id="T_0d213_level0_col3" class="col_heading level0 col3" >Mrs</th>
#       <th id="T_0d213_level0_col4" class="col_heading level0 col4" >Rare</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Sex</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0d213_level0_row0" class="row_heading level0 row0" >female</th>
#       <td id="T_0d213_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_0d213_row0_col1" class="data row0 col1" >185</td>
#       <td id="T_0d213_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_0d213_row0_col3" class="data row0 col3" >126</td>
#       <td id="T_0d213_row0_col4" class="data row0 col4" >3</td>
#     </tr>
#     <tr>
#       <th id="T_0d213_level0_row1" class="row_heading level0 row1" >male</th>
#       <td id="T_0d213_row1_col0" class="data row1 col0" >40</td>
#       <td id="T_0d213_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_0d213_row1_col2" class="data row1 col2" >517</td>
#       <td id="T_0d213_row1_col3" class="data row1 col3" >0</td>
#       <td id="T_0d213_row1_col4" class="data row1 col4" >20</td>
#     </tr>
#   </tbody>
# </table>

# %%
train_df.groupby('Honorifics')['Age'].mean()
# Out:
# Honorifics
# Master     4.574167
# Miss      21.845638
# Mr        32.368090
# Mrs       35.788991
# Rare      45.545455
# Name: Age, dtype: float64

# %% [markdown]
# Теперь знаем средний возраст каждого титула. Присвоим его null-значениям:

# %%
train_df.loc[(train_df['Age'].isnull()) & (train_df['Honorifics']=='Master'), 'Age'] = 5
train_df.loc[(train_df['Age'].isnull()) & (train_df['Honorifics']=='Miss'), 'Age'] = 22
train_df.loc[(train_df['Age'].isnull()) & (train_df['Honorifics']=='Mr'), 'Age'] = 32
train_df.loc[(train_df['Age'].isnull()) & (train_df['Honorifics']=='Mrs'), 'Age'] = 36
train_df.loc[(train_df['Age'].isnull()) & (train_df['Honorifics']=='Rare'), 'Age'] = 46

train_df.isnull().any()
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name           False
# Sex            False
# Age            False
# SibSp          False
# Parch          False
# Ticket         False
# Fare           False
# Cabin           True
# Embarked       False
# Honorifics     False
# dtype: bool

# %% [markdown]
# # Непрерывные величины в дискретные
